# %%
import numpy as np, matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Exercise 2: Predictive accuracy
#
# (Reproducing ISL Figure 2.9 and 2.17)

# %%
import sklearn.datasets, sklearn.neighbors

# %%
iris = sklearn.datasets.load_iris()
print iris.DESCR
# Out:
# Iris Plants Database
#
# Notes
# -----
# Data Set Characteristics:
#     :Number of Instances: 150 (50 in each of three classes)
#     :Number of Attributes: 4 numeric, predictive attributes and the class
#     :Attribute Information:
#         - sepal length in cm
#         - sepal width in cm
#         - petal length in cm
#         - petal width in cm
#         - class:
#                 - Iris-Setosa
#                 - Iris-Versicolour
#                 - Iris-Virginica
#     :Summary Statistics:
#     ============== ==== ==== ======= ===== ====================
#                     Min  Max   Mean    SD   Class Correlation
#     ============== ==== ==== ======= ===== ====================
#     sepal length:   4.3  7.9   5.84   0.83    0.7826
#     sepal width:    2.0  4.4   3.05   0.43   -0.4194
#     petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)
#     petal width:    0.1  2.5   1.20  0.76     0.9565  (high!)
# ...

# %%
X = iris.data[:, :2]  # Q: What does this do?
y = iris.target

# %%
clf = sklearn.neighbors.KNeighborsClassifier(n_neighbors=15, weights='uniform')

# %%
clf.fit(X, y)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_neighbors=15, p=2, weights='uniform')

# %%
# explore the decision boundary. For that, we will predict each
# point in the mesh [x_min, m_max]x[y_min, y_max].
h = .2

x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))

Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])

# %%
# Create color maps
from matplotlib.colors import ListedColormap
cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA', '#AAAAFF'])
cmap_bold = ListedColormap(['#FF0000', '#00aa00', '#0000FF'])

# %%
# Put the result into a color plot
plt.figure(figsize=(8,5))

Z = Z.reshape(xx.shape)
plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

# Plot also the training points
plt.scatter( X[:, 0], X[:, 1], c=y, cmap=cmap_bold, s=40, linewidths=0)
plt.title("3-Class classification (k = %i, weights = '%s')"
             % (15, 'uniform'))

plt.axis('tight')
# Out:
# (3.0299999999999994,
#  8.9700000000000042,
#  0.79000000000000004,
#  5.4099999999999993)

# %%
import mpld3
mpld3.enable_notebook()

# %% [markdown]
# ## Load the ISL data

# %%
import pandas as pd
df = pd.read_csv('ISL_Fig_2_9_data.csv', index_col=0)

# %%
df.head()
# Out:
#         X.1       X.2     Y
# 1  3.295192  0.826891  blue
# 2  1.101317  0.504531  blue
# 3  1.313957  0.135375  blue
# 4 -0.594674 -1.921916  blue
# 5 -0.315310  1.100343  blue

# %%
# fix the color names

df['color'] = df['Y'].map({'red': 'orange', 'blue': 'purple'})

# %%
# make Figure 2.9

plt.figure(figsize=(8,8))
for g, dfg in df.groupby('color'):
    plt.plot(dfg['X.1'], dfg['X.2'], 'o', mec=g, color='w', mew=3, ms=8)
